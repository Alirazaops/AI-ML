# %%
#              Data structures
#       Types of inbuild datastructures
#       • list 
#       • tuple 
#       • set
#       • dict 
#       • range

# %%
l = []

# %%
len(l)
# Out:
# 0

# %%
l1 = [10,20,30,40]

# %%
l1
# Out:
# [10, 20, 30, 40]

# %%
len(l1)
# Out:
# 4

# %%
l1.append(50) # Append function
l1.append(60)
l1.append(70)
l1.append(80)

# %%
l1
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 50, 60, 70, 80]

# %%
l2=[10,1.0, (3+2j),True,'virat']

# %%
l2
# Out:
# [10, 1.0, (3+2j), True, 'virat']

# %%
l3=l1.copy() # copy function
l3
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 50, 60, 70, 80]

# %% [markdown]
# ###

# %%
l3.append(10)
l3.append(['a','b','c'])
l3
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 50, 60, 70, 80, 10, ['a', 'b', 'c']]

# %%
print(l1)
print(l2)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 50, 60, 70, 80]
# [10, 1.0, (3+2j), True, 'virat']
# [10, 20, 30, 40, 50, 60, 70, 80, 50, 60, 70, 80, 10, ['a', 'b', 'c']]

# %%
print(len(l1))
print(len(l2))
print(len(l3))
# Out:
# 12
# 5
# 14

# %%
print(type(l2))
# Out:
# <class 'list'>

# %%
print(id(l1))
# Out:
# 5724223424

# %%
20 in l1
# Out:
# True

# %%
100 in l1
# Out:
# False

# %%
l2.clear() # clear function to list
l2
# Out:
# []

# %%
l3
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 50, 60, 70, 80, 10, ['a', 'b', 'c']]

# %%
l3.count(10)
# Out:
# 2

# %%
l3[1:13] # indexing and sclicing
# Out:
# [20, 30, 40, 50, 60, 70, 80, 50, 60, 70, 80, 10]

# %%
l3[0:10]
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 50, 60]

# %%
l3[1:-2]
# Out:
# [20, 30, 40, 50, 60, 70, 80, 50, 60, 70, 80]

# %%
l3[0:-1]
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 50, 60, 70, 80, 10]

# %%
l3[10:]
# Out:
# [70, 80, 10, ['a', 'b', 'c']]

# %%
l3[:-9]
# Out:
# [10, 20, 30, 40, 50]

# %%
l3[-5:-2]
# Out:
# [60, 70, 80]

# %%
l3[-14:-1]
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 50, 60, 70, 80, 10]
